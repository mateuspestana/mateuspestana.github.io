# %% [markdown]
# # A1 prática — Festival ViraBairro
#
# **Valor total: 6,0 pontos · 5 questões independentes**
#
# Você acaba de entrar na sala de comando do **Festival ViraBairro**, uma programação fictícia feita pelo Observatório Conexão Bairro (OCB). A ideia é simples: transformar pistas, guias e convites sobre cultura, mobilidade, saúde e trabalho em um festival que os moradores realmente queiram descobrir.
#
# Faltam duas semanas para a abertura. A curadoria recebeu o histórico da campanha e precisa de uma equipe de dados para restaurar os registros, montar o placar das trilhas, descobrir estilos de publicação e decidir quais próximas peças merecem reforço de divulgação. Você é essa equipe.
#
# Todos os dados, entidades e resultados desta questão são sintéticos. Não há coleta, requisições web, scraping ou automação nesta avaliação.

# %% [markdown]
# ## Orientações de entrega
#
# - Preencha nome e matrícula na página da prova. Cada questão começa carregando o arquivo indicado; não dependa de variáveis, tabelas ou resultados de outra questão.
# - O ambiente Python já está disponível no navegador. Não instale bibliotecas: escreva código somente nas células indicadas, execute cada uma com **Executar** e registre as interpretações nos campos de resposta.
# - Use somente os arquivos fornecidos, em `dados/`. Não faça coleta externa, requisições web ou automação.
# - Ao clicar em **Baixar entrega .ipynb**, o sistema gera automaticamente o arquivo com seu nome e matrícula. Abra-o no VS Code antes de enviar e confira nome, matrícula, código, respostas e resultados.
# - **É proibida a utilização de IA nesta prova. Se for utilizada, a prova será zerada.**
# - Consulta permitida, exclusivamente: GitHub; [noai.duckduckgo.com](https://noai.duckduckgo.com); documentação oficial de [pandas](https://pandas.pydata.org/docs/), [NumPy](https://numpy.org/doc/) e [scikit-learn](https://scikit-learn.org/stable/); Stack Overflow e YouTube. Google e qualquer outra fonte, ferramenta ou plataforma são proibidos.

# %% [markdown]
# ## Arquivos disponíveis
#
# - dados/publicacoes_brutas.csv: caixa de entrada da curadoria, com problemas intencionais.
# - dados/publicacoes_analise.csv: histórico sintético já tratado para as questões 3, 4 e 5.
# - dados/dicionario-festival-virabairro.md: unidade de análise, significado dos campos e limites.
#
# Abra o **Dicionário de dados** no menu superior antes de começar.

# %% [markdown]
# ---
#
# ## Questão 1 — Credencial de dados (0,5 ponto)
#
# A caixa de entrada chegou sem etiqueta. Antes de abrir qualquer debate editorial, a coordenação precisa de uma credencial curta da base bruta.
#
# Em uma célula de código, carregue dados/publicacoes_brutas.csv e mostre:
#
# 1. as cinco primeiras linhas;
# 2. a quantidade de linhas e colunas; e
# 3. a quantidade de valores ausentes por coluna, mostrando somente as colunas que têm ao menos uma ausência.
#
# Na Markdown, explique em até duas frases uma limitação que impeça tratar esses resultados como retrato de todas as redes, públicos ou bairros.

# %%
# Questão 1
# Importe pandas, carregue dados/publicacoes_brutas.csv e faça a credencial solicitada.
# Mostre as cinco primeiras linhas, as dimensões e somente as colunas com valores ausentes.

# %% [markdown]
# **Resposta da Questão 1 — limite de uso:**
#
# _Escreva aqui em até duas frases._

# %% [markdown]
# ---
#
# ## Questão 2 — Oficina de restauro (1,0 ponto)
#
# Os cartões da campanha vieram com etiquetas tortas, datas em formatos diferentes, uma ficha repetida e algumas lacunas. Restaure a base sem inventar informação.
#
# Parta novamente de dados/publicacoes_brutas.csv, em uma nova variável. Faça o tratamento necessário para:
#
# 1. remover duplicidade por id_publicacao;
# 2. padronizar os valores de tema para uma forma consistente;
# 3. converter data_publicacao e as colunas numéricas usadas no cálculo para tipos adequados;
# 4. tratar ausências ou valores inválidos de maneira justificada; e
# 5. criar taxa_utilidade_pct, definida por:
#
# $$\frac{compartilhamentos + salvamentos}{alcance} \times 100$$
#
# Depois, produza uma tabela por tema com o número de publicações e a **mediana** de taxa_utilidade_pct, ordenada da maior para a menor mediana. Não precisa salvar arquivo.
#
# Na Markdown, registre as decisões de limpeza em até quatro frases. Se descartar, preencher ou converter algo, diga por quê.

# %%
# Questão 2
# Recarregue dados/publicacoes_brutas.csv em uma nova variável.
# Faça a limpeza solicitada e calcule taxa_utilidade_pct.
# Produza a tabela-resumo por tema, com quantidade de publicações e mediana da taxa.

# %% [markdown]
# **Resposta da Questão 2 — decisões de restauro:**
#
# _Explique aqui as decisões para valores ausentes, inválidos ou duplicados, em até quatro frases._

# %% [markdown]
# ---
#
# ## Questão 3 — Painel da curadoria (1,0 ponto)
#
# A curadoria tem quatro trilhas e só consegue destacar uma delas no mural de entrada do festival. O mural deve privilegiar conteúdo que as pessoas têm vontade de **guardar ou repassar**.
#
# Use **somente** dados/publicacoes_analise.csv. Crie taxa_utilidade_pct com a mesma fórmula da questão anterior. Em seguida:
#
# 1. monte uma tabela com a mediana da taxa por tema; e
# 2. faça um gráfico de barras que permita comparar as quatro trilhas.
#
# O gráfico deve ter título que comunique a pergunta, eixos nomeados e a indicação "Fonte: dados sintéticos do Festival ViraBairro (2026)" no próprio gráfico.
#
# Na Markdown, escreva uma recomendação de 3 a 5 frases para a curadoria: indique uma trilha para o mural, explique o que a mediana representa e apresente uma limitação. A escolha é editorial; não afirme causalidade.

# %%
# Questão 3
# Carregue dados/publicacoes_analise.csv e crie taxa_utilidade_pct.
# Calcule a mediana por tema e faça o gráfico de barras solicitado.
# Inclua título, rótulos dos eixos e a fonte no próprio gráfico.

# %% [markdown]
# **Resposta da Questão 3 — recado para a curadoria:**
#
# _Escreva aqui de 3 a 5 frases._

# %% [markdown]
# ---
# ## Questão 4 — Mapa da programação (1,5 ponto)
#
# A curadoria quer entender como os **temas** e os **formatos** se combinam na programação. Não basta olhar cada variável isoladamente: uma trilha pode funcionar de maneira diferente em vídeo, carrossel ou imagem.
#
# Use **somente** `dados/publicacoes_analise.csv`. Crie uma tabela com uma linha para cada combinação de `tema` e `formato`, contendo:
#
# 1. número de publicações; e
# 2. mediana de `taxa_engajamento_pct`.
#
# Ordene a tabela da maior para a menor mediana. Depois, faça um gráfico de barras que compare as combinações de tema e formato. O gráfico deve ter título informativo, eixos nomeados e a fonte **“Fonte: dados sintéticos do Festival ViraBairro (2026)”** no próprio gráfico.
#
# Na Markdown, escreva de 4 a 6 frases: destaque uma combinação que mereça teste editorial, explique por que comparar duas variáveis é diferente de analisar apenas uma e registre uma limitação da base.

# %%
# Questão 4
# Carregue dados/publicacoes_analise.csv em uma nova variável.
# Agrupe por tema e formato, calcule a quantidade de publicações e a mediana de taxa_engajamento_pct.
# Ordene a tabela e faça um gráfico de barras que compare as combinações.
# Inclua título, rótulos dos eixos e a fonte no próprio gráfico.

# %% [markdown]
# **Resposta da Questão 4 — leitura da programação:**
#
# _Escreva aqui de 4 a 6 frases._

# %% [markdown]
# ---
#
# ## Questão 5 — Bússola de impulso (2,0 pontos)
#
# Na véspera do festival, a equipe de rua consegue dar reforço extra a poucas publicações. A pergunta agora é anterior à postagem: quais peças têm maior chance de receber o selo **"merece impulso"**?
#
# Use **somente** dados/publicacoes_analise.csv. Crie mereceu_impulso: valor 1 quando taxa_engajamento_pct estiver acima do percentil 75 da própria base, e 0 nos demais.
#
# 1. Na Markdown, diga qual tipo de aprendizado de máquina é adequado — regressão, classificação ou clusterização — e explique brevemente por que os outros dois não respondem diretamente a essa decisão.
# 2. Use apenas características disponíveis antes da publicação: `tema`, `formato`, `seguidores_autor`, `videos_autor`, `tamanho_legenda`, `n_emojis`, `n_hashtags`, `hora`, `dia_semana` e `duracao_segundos`. Transforme as categorias em colunas numéricas quando necessário. Não use identificador, alcance, interações ou `taxa_engajamento_pct`: isso seria vazamento de dados.
# 3. Separe treino e teste com `test_size=0.25`, `random_state=42` e estratificação do alvo.
# 4. Compare o baseline que sempre prevê "não merece impulso" com **três** modelos que você escolher desta lista: `LogisticRegression`, `DecisionTreeClassifier`, `RandomForestClassifier`, `ExtraTreesClassifier`, `AdaBoostClassifier` e `GaussianNB`.
# 5. No conjunto de teste, apresente precisão, recall e F1 do baseline e dos três modelos. Escolha o melhor pelo F1 e exiba sua matriz de confusão.
#
# Na resposta final, informe o modelo escolhido e explique, em até cinco frases, o que falso positivo e falso negativo significam para a equipe de rua. Você pode consultar os materiais das aulas para lembrar a sintaxe; as decisões e interpretações devem ser suas.

# %% [markdown]
# **Resposta da Questão 5.1 — tipo de modelo:**
#
# _Escreva aqui em até quatro frases._

# %%
# Questão 5
# Carregue dados/publicacoes_analise.csv em uma nova variável e crie mereceu_impulso.
# Prepare somente as características permitidas e transforme as categorias quando necessário.
# Faça treino/teste, baseline e três modelos escolhidos da lista do enunciado.
# Mostre precisão, recall e F1; depois, exiba a matriz de confusão do modelo escolhido.

# %% [markdown]
# **Resposta da Questão 5.5 — decisão e riscos de erro:**
#
# _Indique o modelo escolhido pelo F1 e explique falso positivo e falso negativo no contexto do festival, em até cinco frases._

# %% [markdown]
# ---
#
# ## Antes de enviar
#
# Baixe a entrega e abra o arquivo no **VS Code**. Confirme que ele contém seu nome, matrícula, respostas, código e resultados executados. Só então envie o notebook pela plataforma indicada pelo professor.
